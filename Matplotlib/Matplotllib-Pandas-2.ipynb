# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Bar plot from a pandas DataFrame

# %%
x = np.random.rand(10, 4)
x
# Out:
# array([[0.75472945, 0.68767847, 0.69272959, 0.79798379],
#        [0.35842015, 0.17868438, 0.00997123, 0.6582153 ],
#        [0.76512384, 0.16525026, 0.79504475, 0.70991091],
#        [0.29990215, 0.42236435, 0.07280029, 0.63362107],
#        [0.41903517, 0.7373659 , 0.25035125, 0.37574333],
#        [0.55594315, 0.31675784, 0.46772307, 0.980591  ],
#        [0.70225274, 0.46126243, 0.06254492, 0.74361172],
#        [0.33714796, 0.70064553, 0.20626276, 0.41869445],
#        [0.26048766, 0.77853348, 0.1718302 , 0.99003298],
#        [0.39176893, 0.70602859, 0.06737209, 0.75398394]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.754729  0.687678  0.692730  0.797984
# 1  0.358420  0.178684  0.009971  0.658215
# 2  0.765124  0.165250  0.795045  0.709911
# 3  0.299902  0.422364  0.072800  0.633621
# 4  0.419035  0.737366  0.250351  0.375743
# 5  0.555943  0.316758  0.467723  0.980591
# 6  0.702253  0.461262  0.062545  0.743612
# 7  0.337148  0.700646  0.206263  0.418694
# 8  0.260488  0.778533  0.171830  0.990033
# 9  0.391769  0.706029  0.067372  0.753984

# %%
# 1st Method

df.plot.bar();

# %%
df.plot(kind='bar');

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %% [markdown]
# ## Histogram

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
# Changing bin 

car_sales['Odometer (KM)'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease['age'].plot.hist(bins=50);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# subplots for multiple figs
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %% [markdown]
# ### Plotting with pandas using OO Methods

# %%
# Perform data analysis on patients over 50
over_50 = heart_disease[heart_disease['age'] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
over_50.plot(kind='scatter',x='age', y='chol', c='target', figsize=(10, 6));

# %%
fig, ax = plt.subplots(figsize=(10, 6))

over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target',
            ax=ax);

ax.set_xlim([45, 100]);

# %%
# Adding figures & axes
fig, ax = plt.subplots(figsize=(10, 6))

# Plot data directly to the axes instance
scatter = ax.scatter(over_50['age'],
                    over_50['chol'],
                    c=over_50['target'])

# Customize the plot parameters
ax.set(title="Heart disease & Cholesterol Levels",
      xlabel="Age",
      ylabel="cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(),
         title="target")

ax.axhline(over_50['chol'].mean(),
        linestyle='--');

# %%
# Setup plot (2 rows, 1 column)
fig, (ax0, ax1) = plt.subplots(nrows=2, # 2 rows
                               ncols=1, # 1 column 
                               sharex=True, # both plots should use the same x-axis 
                               figsize=(10, 8))

# ---------- Axis 0: Heart Disease and Cholesterol Levels ----------

# Add data for ax0
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average");

# ---------- Axis 1: Heart Disease and Max Heart Rate Levels ----------

# Add data for ax1
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Title the figure
fig.suptitle('Heart Disease Analysis', 
             fontsize=16, 
             fontweight='bold');
